# %%
from spacy.lang.pl import Polish
from spacy.tokenizer import Tokenizer
nlp = Polish()
tokenizer = Tokenizer(nlp.vocab)

# %%
from os import listdir
from os.path import isfile,join
billPath = './bills/'
bills = [f for f in listdir(billPath) if isfile(join(billPath, f))]

bills_bigrams = {}
bills_trigrams = {}
bills_single_grams = {}
# bills_bigram_list = []

for b in bills:
    bPath = billPath + b
    f = open(bPath,encoding='utf-8')
    content = f.read()
    content = content.lower()
    tokens = tokenizer(content)
    frequency = {}
    
    for t in range(len(tokens)-1):
        k1 = tokens[t].text
        k2 = tokens[t + 1].text
        bigram = (k1,k2)
        bills_bigrams[(k1,k2)] = bills_bigrams.get((k1,k2),0) + 1
        bills_single_grams[k1] = bills_single_grams.get(k1,0) + 1
    for t in range(len(tokens)-2):
        k1 = tokens[t].text
        k2 = tokens[t + 1].text
        k3 = tokens[t + 2].text
        bills_trigrams[(k1,k2,k3)] = bills_trigrams.get((k1,k2,k3),0) + 1
        
    k1 = tokens[len(tokens)-1]
    bills_single_grams[k1] = bills_single_grams.get(k1,0) + 1

# %%
len(bills_bigrams)
# Out:
# 1097691

# %%
import regex as re
to_remove = []

for i in bills_bigrams:
    t1,t2 = i
    tmp1,tmp2 = re.search(r"\p{L}+",t1),re.search(r"\p{L}+",t2)
    if tmp1 is None or tmp2 is None or len(tmp1.group(0)) != len(t1) or len(tmp2.group(0)) != len(t2) :
        to_remove += [(t1,t2)]

len(to_remove)
# Out:
# 657079

# %%
for i in to_remove:
    bills_bigrams.pop(i)
len(bills_bigrams)
# Out:
# 440612

# %%
i = 0
for b in bills_bigrams:
    if i == 500:
        break
    print(str(i) + 
          str(bills_bigrams[b])+ '\t' + b[0] + ' ' +  b[1])
    i += 1
# Out:
# 09023	z dnia
# 11175	o zmianie
# 2829	zmianie ustawy
# 31412	ustawy o
# 4496	o podatku
# 5362	podatku od
# 6248	od towarów
# 7505	towarów i
# 8359	i usług
# 9897	oraz o
# 1043	podatku akcyzowym
# 114286	w ustawie
# 123636	ustawie z
# 13119	usług oraz
# 147898	i nr
# 151742	wprowadza się
# 161638	się następujące
# 1737	dotychczasowa treść
# 1837	treść otrzymuje
# 1940	otrzymuje oznaczenie
# 207995	dodaje się
# 21649	rada ministrów
# 22103	ministrów może
# 236601	w drodze
# 2419	towary i
# 251267	z wyjątkiem
# 2618	wyjątkiem wyrobów
# 27293	wyrobów akcyzowych
# 285	akcyzowych i
# 29120	i wyrobów
# 3031	z metali
# 31372	do których
# 32142	których nie
# 331350	nie stosuje
# 345780	stosuje się
# 35149	się przepisów
# 363626	w pkt
# 374485	zastępuje się
# 382565	się wyrazami
# 39616	kropkę zastępuje
# 40161	się średnikiem
# 41168	średnikiem i
# 42845	i dodaje
# 4388	dodaje wyrazy
# 442	przypadkach właściwym
# 454	właściwym urzędem
# 465	urzędem skarbowym
# 474	skarbowym jest
# 482	jest drugi
# 494	drugi urząd
# 5012	jeżeli sprzedaż
# 516	sprzedaż towaru
# 5253	towaru lub
# 5317	lub wykonanie
# 544	wykonanie usługi
# 551	usługi powinno
# 56150	powinno być
# 579	być potwierdzone
# 581	fakturą lub
# 591	lub rachunkiem
# 6018	podatkowy powstaje
# 6187	powstaje z
# 62324	z chwilą
# 633	chwilą wystawienia
# 643	wystawienia faktury
# 656	faktury lub
# 66727	nie później
# 67125	później jednak
# 68635	jednak niż
# 69490	niż w
# 7014	dniu od
# 7196	dnia wydania
# 723	wydania towaru
# 7326	lub wykonania
# 741	wystawienie faktury
# 756	lub rachunku
# 761	rachunku uproszczonego
# 771	uproszczonego następuje
# 7825	następuje nie
# 79653	później niż
# 8084	w ostatnim
# 8148	ostatnim dniu
# 821628	w którym
# 8323	którym wydano
# 841	wydano towar
# 8512	towar lub
# 861	lub wykonano
# 87342	się również
# 88231	również w
# 894595	w przypadku
# 905	przypadku eksportu
# 9116	wywóz towarów
# 921	towarów nastąpi
# 9325	nastąpi w
# 94939	w ciągu
# 9515	ciągu sześciu
# 9673	sześciu miesięcy
# 974776	od dnia
# 98268	dnia otrzymania
# 992	eksporter przedstawi
# 1005	przedstawi w
# 101148	w urzędzie
# 10216	urzędzie skarbowym
# 1031	skarbowym zabezpieczenie
# 1041	majątkowe kwoty
# 1053	kwoty zwrotu
# 10618	zwrotu różnicy
# 1075051	o której
# 1085193	której mowa
# 10927728	mowa w
# 1107	import towarów
# 1118	towarów zwolnionych
# 11247	zwolnionych od
# 113127	od cła
# 11423	cła na
# 1155888	na podstawie
# 1162957	ustawy z
# 11718	prawo celne
# 1184101	oraz z
# 1191	nawiasie zastępuje
# 1202490	skreśla się
# 1212053	się wyrazy
# 122121	niż na
# 123731	przypadku gdy
# 1241	gdy zaprzestanie
# 1251	zaprzestanie wykonania
# 12643	wykonania czynności
# 12718	czynności podlegających
# 1282	opodatkowaniu nie
# 12989	nie zostało
# 13010	zostało zgłoszone
# 1315	zgłoszone zgodnie
# 1322450	zgodnie z
# 13339	który dokonał
# 134333	z urzędu
# 1351	urzędu podatnika
# 13615	podatnika z
# 1372062	a w
# 138422	w przypadkach
# 139200	przypadkach określonych
# 1407	następuje również
# 1411	również unieważnienie
# 1421	unieważnienie numeru
# 1431680	się odpowiednio
# 144704	odpowiednio do
# 14584	do kwoty
# 1464	podatku wynikającej
# 147167	wynikającej z
# 1489	z deklaracji
# 1491981	się do
# 15021	do podatników
# 1515	podatników zwolnionych
# 15232	usług na
# 15319	oraz podmiotów
# 1542	wykonujących wyłącznie
# 1559	wyłącznie czynności
# 1562	czynności zwolnione
# 157107	zwolnione od
# 158143	od podatku
# 159525	lub na
# 160724	podstawie przepisów
# 161512	wydanych na
# 1621229	chyba że
# 1633	że przysługuje
# 16413	przysługuje im
# 16510	zwrot różnicy
# 16619	różnicy podatku
# 16730	podatku lub
# 1685	lub zwrot
# 1698	zwrot podatku
# 17014	podatku naliczonego
# 1711	naliczonego zgodnie
# 172125	zwalnia się
# 173446	się od
# 17434	u których
# 17550	których wartość
# 17620	wartość sprzedaży
# 17763	sprzedaży towarów
# 17850	towarów w
# 1791536	w rozumieniu
# 1803316	a także
# 1817	także wartość
# 1823	wartość eksportu
# 18366	towarów lub
# 18451	lub usług
# 18510	usług nie
# 1869	nie przekroczyła
# 1872	przekroczyła łącznie
# 18812	łącznie w
# 18987	w poprzednim
# 190154	roku podatkowym
# 1912	opłacających podatek
# 19294	podatek dochodowy
# 19316	dochodowy w
# 1941029	w formie
# 19574	formie karty
# 1964593	w zakresie
# 19749	zakresie działalności
# 19863	działalności objętej
# 1991	objętej tą
# 200901	z uwzględnieniem
# 20112609	o których
# 20213019	których mowa
# 2031	mogą zrezygnować
# 20457	ze zwolnienia
# 2055	zwolnienia określonego
# 206883	określonego w
# 207275	pod warunkiem
# 2081	warunkiem zawiadomienia
# 209406	o tym
# 2101	tym zamiarze
# 2111	zamiarze właściwego
# 21258	właściwego urzędu
# 213138	urzędu skarbowego
# 2143	przed początkiem
# 2151	którym rezygnują
# 2161	rezygnacja obowiązuje
# 21717	obowiązuje do
# 218244	do końca
# 21976	końca roku
# 220132	jeżeli wartość
# 2213	towarów u
# 2226	u podatników
# 22331	podatku na
# 2242	zwolnienie traci
# 225127	traci moc
# 22618	moc w
# 22734	w momencie
# 2284	przekroczenie tej
# 22972	obowiązek podatkowy
# 2302	chwilą przekroczenia
# 2315	przekroczenia tej
# 2322	a opodatkowaniu
# 2333	podlega nadwyżka
# 2341	nadwyżka ponad
# 23511	ponad tę
# 236401	za zgodą
# 23712	zgodą właściwego
# 2383	skarbowego podatnik
# 23916	podatnik może
# 2408	może zmniejszyć
# 2414	zmniejszyć podatek
# 2424	należny o
# 24319	o podatek
# 24480	wynikający z
# 24512	z rachunków
# 2461	uproszczonych dokumentujących
# 2473	dokumentujących zakupy
# 2483	zakupy dokonane
# 2491336	przed dniem
# 25012	dniem utraty
# 2512	warunkiem sporządzenia
# 25219	spisu z
# 25323	z natury
# 2544	natury zapasów
# 2554	zapasów tych
# 25631	tych towarów
# 2572	towarów posiadanych
# 258901	w dniu
# 2591	dniu przekroczenia
# 2601	przekroczenia kwoty
# 2613	przez wartość
# 2621	towarów określoną
# 2631	kwoty prowizji
# 2646	podatników dokonujących
# 2651	sprzedaży będącej
# 26617	będącej przedmiotem
# 2679	przedmiotem umowy
# 26814	wartość sprzedanych
# 26912	sprzedanych towarów
# 2701	towarów będącej
# 2713	podatnicy będący
# 2722	będący zakładami
# 2735	zakładami pracy
# 27420	pracy chronionej
# 2753	chronionej w
# 2761099	przepisów o
# 27782	o zatrudnieniu
# 27879	zatrudnieniu i
# 27923	i rehabilitacji
# 28070	rehabilitacji zawodowej
# 281100	osób niepełnosprawnych
# 2821	niepełnosprawnych mogą
# 2832	mogą wybrać
# 2841	wybrać zwolnienie
# 28590	zwolnienie od
# 286198	bez względu
# 2871350	względu na
# 28815	na wartość
# 2896	warunkiem złożenia
# 29076	złożenia przez
# 291109	przez podatnika
# 2921	podatnika pisemnego
# 2931	oświadczenia we
# 29465	we właściwym
# 29515	właściwym urzędzie
# 2961	podatnik rozpoczynający
# 2971	rozpoczynający wykonywanie
# 29878	wykonywanie czynności
# 29932	czynności określonych
# 30098	ciągu roku
# 301104	roku podatkowego
# 3022	podatkowego może
# 3034	może wybrać
# 3042	jeżeli przewidywana
# 3054	przewidywana przez
# 306154	określona w
# 3074	w złożonym
# 30829	nie przekroczy
# 30913	w proporcji
# 31013	proporcji do
# 311150	do okresu
# 3121	prowadzonej sprzedaży
# 3132	kwoty wymienionej
# 314414	wymienionej w
# 3151	podatnik składa
# 31611	składa oświadczenie
# 3178	oświadczenie w
# 3183	dniem dokonania
# 3193	dokonania pierwszej
# 3203	pierwszej sprzedaży
# 3211	towarów określona
# 3226	określona zgodnie
# 3232	zostanie przekroczona
# 3244	przekroczona w
# 3252	moc od
# 32614	od momentu
# 3271	momentu przekroczenia
# 3283	opodatkowaniu podlega
# 3291	nadwyżka sprzedaży
# 3305	ponad wartość
# 3311	wartość określoną
# 3329	określoną zgodnie
# 3333	a obowiązek
# 33425	zdanie trzecie
# 3354	trzecie stosuje
# 3366	jeżeli podatnicy
# 3372	podatnicy określeni
# 33814	określeni w
# 3398	związki z
# 3401	tak układają
# 3413	układają swoje
# 3421	uzyskują wartość
# 3431	towarów znacznie
# 3441	znacznie niższą
# 34515	niższą niż
# 3461	uzyskaliby w
# 3471	gdyby związek
# 3485	związek ten
# 349117	ten nie
# 350859	w wyniku
# 3518	wyniku tych
# 3522	tych związków
# 3531	związków nastąpiło
# 3541	nastąpiło zmniejszenie
# 3551	zmniejszenie wpływów
# 3561	podatku traci
# 35757	początku roku
# 3581	ulega corocznie
# 3592	corocznie podwyższeniu
# 36010	podwyższeniu w
# 36171	w stopniu
# 36211	odpowiadającym wskaźnikowi
# 3636	wskaźnikowi cen
# 3644	cen konsumpcyjnych
# 3654	konsumpcyjnych towarów
# 36669	usług w
# 3671215	w okresie
# 36817	okresie pierwszych
# 3697	pierwszych trzech
# 37010	trzech kwartałów
# 371123	roku poprzedzającego
# 372106	poprzedzającego rok
# 37326	rok kalendarzowy
# 3749	kalendarzowy w
# 3751203	w stosunku
# 3761124	stosunku do
# 377204	tego samego
# 3784	samego okresu
# 3798	okresu roku
# 3802	podatników określonych
# 3813809	określonych w
# 3828	do importu
# 38330	wyroby z
# 38414	metali szlachetnych
# 3851	szlachetnych lub
# 386419	lub z
# 387201	z udziałem
# 3882	wyrobów wymienionych
# 389364	w załączniku
# 390278	załączniku nr
# 39157	świadczących usługi
# 3922	usługi prawnicze
# 3932	prawnicze oraz
# 39413	oraz usługi
# 395122	usługi w
# 396264	minister finansów
# 397160	i pkt
# 3982	uwzględnieniem klasyfikacji
# 3993	klasyfikacji wydanych
# 40043	o statystyce
# 40165	finansów w
# 4021564	w porozumieniu
# 4031606	porozumieniu z
# 40477	z prezesem
# 40518	prezesem głównego
# 406135	urzędu statystycznego
# 4071	statystycznego ustala
# 4082	ustala do
# 40923	listopada roku
# 4107	uwzględnieniem zasady
# 4113	zasady określonej
# 412577	określonej w
# 41313	tę kwotę
# 4143	kwotę do
# 41535	do pełnych
# 416340	w zdaniu
# 41760	zdaniu drugim
# 41819	drugim po
# 419540	po wyrazie
# 420236	się wyraz
# 42118	podstawą opodatkowania
# 42279	opodatkowania w
# 4239	w imporcie
# 4248	imporcie towarów
# 4257	towarów jest
# 42650	jest wartość
# 42712	celna powiększona
# 42838	powiększona o
# 42920	o należne
# 4306	należne cło
# 4318	cło i
# 43211	i podatek
# 4337	przedmiotem importu
# 4342	importu są
# 43522	są towary
# 4364	towary opodatkowane
# 4377	opodatkowane podatkiem
# 43816	wartość celną
# 4391	celną powiększoną
# 44021	powiększoną o
# 4411	importowy zwiększa
# 44225	zwiększa się
# 44329	również o
# 444673	się wyrazem
# 44511	obniżenie kwoty
# 44631	kwoty podatku
# 447476	następuje w
# 44820	w rozliczeniu
# 44910	rozliczeniu za
# 45014	którym podatnik
# 4514	rachunek uproszczony
# 4522	uproszczony w
# 45376	przypadku określonym
# 45410	lub dokument
# 4554	dokument odprawy
# 456420	albo w
# 4571	kropkę skreśla
# 45888	się i
# 4591227	miesięcy od
# 46086	od końca
# 4613	podatnik otrzymał
# 4622	otrzymał fakturę
# 46333	przypadku nabycia
# 46416	procentowy udział
# 4651	udział wartości
# 4666	wartości sprzedaży
# 4676	towarów opodatkowanych
# 46814	w wartości
# 4691	sprzedaży ogółem
# 4701	ogółem oblicza
# 471113	oblicza się
# 4721470	się na
# 4731	podstawie sprzedaży
# 4748	sprzedaży z
# 47512	z ostatnich
# 4762	ostatnich sześciu
# 4774	podatnicy dokonujący
# 4785	okresie krótszym
# 47974	krótszym niż
# 48019	niż sześć
# 48123	sześć miesięcy
# 4821	miesięcy obliczają
# 4832	udział zgodnie
# 484266	przy czym
# 4853	czym po
# 4861539	po upływie
# 48721	od rozpoczęcia
# 48855	rozpoczęcia działalności
# 4891	działalności wyliczają
# 4901	wyliczają ten
# 4914	i dokonują
# 4921	dokonują korekty
# 4933	korekty podatku
# 49418	gdy kwota
# 4952	kwota zwrotu
# 4964	podatku dla
# 4978	dla podatnika
# 4982	dokonującego sprzedaży
# 4991	opodatkowanych stawkami

# %%
from spacy.lang.pl import Polish
from spacy.tokenizer import Tokenizer
nlp = Polish()
tokenizer = Tokenizer(nlp.vocab)

from os import listdir
from os.path import isfile,join
billPath = './bills/'
bills = [f for f in listdir(billPath) if isfile(join(billPath, f))]

bills_bigrams = {}
bills_trigrams = {}
bills_single_grams = {}
# bills_bigram_list = []

for b in bills:
    bPath = billPath + b
    f = open(bPath,encoding='utf-8')
    content = f.read()
    content = content.lower()
    tokens = tokenizer(content)
    frequency = {}
    
    for t in range(len(tokens)-1):
        k1 = tokens[t].text
        k2 = tokens[t + 1].text
        tmp1,tmp2 = re.search(r"\p{L}+",k1),re.search(r"\p{L}+",k2)
        if tmp1 is None or tmp2 is None or len(tmp1.group(0)) != len(k1) or len(tmp2.group(0)) != len(k2) :
            continue
        
        bigram = (k1,k2)
        bills_bigrams[(k1,k2)] = bills_bigrams.get((k1,k2),0) + 1
        bills_single_grams[k1] = bills_single_grams.get(k1,0) + 1
    for t in range(len(tokens)-2):
        k1 = tokens[t].text
        k2 = tokens[t + 1].text
        k3 = tokens[t + 2].text
        bills_trigrams[(k1,k2,k3)] = bills_trigrams.get((k1,k2,k3),0) + 1
        
    k1 = tokens[len(tokens)-1]
    bills_single_grams[k1] = bills_single_grams.get(k1,0) + 1

# %%
i = 0
for b in bills_bigrams:
    if i == 500:
        break
    print(str(i) + 
          str(bills_bigrams[b])+ '\t' + b[0] + ' ' +  b[1])
    i += 1
# Out:
# 09023	z dnia
# 11175	o zmianie
# 2829	zmianie ustawy
# 31412	ustawy o
# 4496	o podatku
# 5362	podatku od
# 6248	od towarów
# 7505	towarów i
# 8359	i usług
# 9897	oraz o
# 1043	podatku akcyzowym
# 114286	w ustawie
# 123636	ustawie z
# 13119	usług oraz
# 147898	i nr
# 151742	wprowadza się
# 161638	się następujące
# 1737	dotychczasowa treść
# 1837	treść otrzymuje
# 1940	otrzymuje oznaczenie
# 207995	dodaje się
# 21649	rada ministrów
# 22103	ministrów może
# 236601	w drodze
# 2419	towary i
# 251267	z wyjątkiem
# 2618	wyjątkiem wyrobów
# 27293	wyrobów akcyzowych
# 285	akcyzowych i
# 29120	i wyrobów
# 3031	z metali
# 31372	do których
# 32142	których nie
# 331350	nie stosuje
# 345780	stosuje się
# 35149	się przepisów
# 363626	w pkt
# 374485	zastępuje się
# 382565	się wyrazami
# 39616	kropkę zastępuje
# 40161	się średnikiem
# 41168	średnikiem i
# 42845	i dodaje
# 4388	dodaje wyrazy
# 442	przypadkach właściwym
# 454	właściwym urzędem
# 465	urzędem skarbowym
# 474	skarbowym jest
# 482	jest drugi
# 494	drugi urząd
# 5012	jeżeli sprzedaż
# 516	sprzedaż towaru
# 5253	towaru lub
# 5317	lub wykonanie
# 544	wykonanie usługi
# 551	usługi powinno
# 56150	powinno być
# 579	być potwierdzone
# 581	fakturą lub
# 591	lub rachunkiem
# 6018	podatkowy powstaje
# 6187	powstaje z
# 62324	z chwilą
# 633	chwilą wystawienia
# 643	wystawienia faktury
# 656	faktury lub
# 66727	nie później
# 67125	później jednak
# 68635	jednak niż
# 69490	niż w
# 7014	dniu od
# 7196	dnia wydania
# 723	wydania towaru
# 7326	lub wykonania
# 741	wystawienie faktury
# 756	lub rachunku
# 761	rachunku uproszczonego
# 771	uproszczonego następuje
# 7825	następuje nie
# 79653	później niż
# 8084	w ostatnim
# 8148	ostatnim dniu
# 821628	w którym
# 8323	którym wydano
# 841	wydano towar
# 8512	towar lub
# 861	lub wykonano
# 87342	się również
# 88231	również w
# 894595	w przypadku
# 905	przypadku eksportu
# 9116	wywóz towarów
# 921	towarów nastąpi
# 9325	nastąpi w
# 94939	w ciągu
# 9515	ciągu sześciu
# 9673	sześciu miesięcy
# 974776	od dnia
# 98268	dnia otrzymania
# 992	eksporter przedstawi
# 1005	przedstawi w
# 101148	w urzędzie
# 10216	urzędzie skarbowym
# 1031	skarbowym zabezpieczenie
# 1041	majątkowe kwoty
# 1053	kwoty zwrotu
# 10618	zwrotu różnicy
# 1075051	o której
# 1085193	której mowa
# 10927728	mowa w
# 1107	import towarów
# 1118	towarów zwolnionych
# 11247	zwolnionych od
# 113127	od cła
# 11423	cła na
# 1155888	na podstawie
# 1162957	ustawy z
# 11718	prawo celne
# 1184101	oraz z
# 1191	nawiasie zastępuje
# 1202490	skreśla się
# 1212053	się wyrazy
# 122121	niż na
# 123731	przypadku gdy
# 1241	gdy zaprzestanie
# 1251	zaprzestanie wykonania
# 12643	wykonania czynności
# 12718	czynności podlegających
# 1282	opodatkowaniu nie
# 12989	nie zostało
# 13010	zostało zgłoszone
# 1315	zgłoszone zgodnie
# 1322450	zgodnie z
# 13339	który dokonał
# 134333	z urzędu
# 1351	urzędu podatnika
# 13615	podatnika z
# 1372062	a w
# 138422	w przypadkach
# 139200	przypadkach określonych
# 1407	następuje również
# 1411	również unieważnienie
# 1421	unieważnienie numeru
# 1431680	się odpowiednio
# 144704	odpowiednio do
# 14584	do kwoty
# 1464	podatku wynikającej
# 147167	wynikającej z
# 1489	z deklaracji
# 1491981	się do
# 15021	do podatników
# 1515	podatników zwolnionych
# 15232	usług na
# 15319	oraz podmiotów
# 1542	wykonujących wyłącznie
# 1559	wyłącznie czynności
# 1562	czynności zwolnione
# 157107	zwolnione od
# 158143	od podatku
# 159525	lub na
# 160724	podstawie przepisów
# 161512	wydanych na
# 1621229	chyba że
# 1633	że przysługuje
# 16413	przysługuje im
# 16510	zwrot różnicy
# 16619	różnicy podatku
# 16730	podatku lub
# 1685	lub zwrot
# 1698	zwrot podatku
# 17014	podatku naliczonego
# 1711	naliczonego zgodnie
# 172125	zwalnia się
# 173446	się od
# 17434	u których
# 17550	których wartość
# 17620	wartość sprzedaży
# 17763	sprzedaży towarów
# 17850	towarów w
# 1791536	w rozumieniu
# 1803316	a także
# 1817	także wartość
# 1823	wartość eksportu
# 18366	towarów lub
# 18451	lub usług
# 18510	usług nie
# 1869	nie przekroczyła
# 1872	przekroczyła łącznie
# 18812	łącznie w
# 18987	w poprzednim
# 190154	roku podatkowym
# 1912	opłacających podatek
# 19294	podatek dochodowy
# 19316	dochodowy w
# 1941029	w formie
# 19574	formie karty
# 1964593	w zakresie
# 19749	zakresie działalności
# 19863	działalności objętej
# 1991	objętej tą
# 200901	z uwzględnieniem
# 20112609	o których
# 20213019	których mowa
# 2031	mogą zrezygnować
# 20457	ze zwolnienia
# 2055	zwolnienia określonego
# 206883	określonego w
# 207275	pod warunkiem
# 2081	warunkiem zawiadomienia
# 209406	o tym
# 2101	tym zamiarze
# 2111	zamiarze właściwego
# 21258	właściwego urzędu
# 213138	urzędu skarbowego
# 2143	przed początkiem
# 2151	którym rezygnują
# 2161	rezygnacja obowiązuje
# 21717	obowiązuje do
# 218244	do końca
# 21976	końca roku
# 220132	jeżeli wartość
# 2213	towarów u
# 2226	u podatników
# 22331	podatku na
# 2242	zwolnienie traci
# 225127	traci moc
# 22618	moc w
# 22734	w momencie
# 2284	przekroczenie tej
# 22972	obowiązek podatkowy
# 2302	chwilą przekroczenia
# 2315	przekroczenia tej
# 2322	a opodatkowaniu
# 2333	podlega nadwyżka
# 2341	nadwyżka ponad
# 23511	ponad tę
# 236401	za zgodą
# 23712	zgodą właściwego
# 2383	skarbowego podatnik
# 23916	podatnik może
# 2408	może zmniejszyć
# 2414	zmniejszyć podatek
# 2424	należny o
# 24319	o podatek
# 24480	wynikający z
# 24512	z rachunków
# 2461	uproszczonych dokumentujących
# 2473	dokumentujących zakupy
# 2483	zakupy dokonane
# 2491336	przed dniem
# 25012	dniem utraty
# 2512	warunkiem sporządzenia
# 25219	spisu z
# 25323	z natury
# 2544	natury zapasów
# 2554	zapasów tych
# 25631	tych towarów
# 2572	towarów posiadanych
# 258901	w dniu
# 2591	dniu przekroczenia
# 2601	przekroczenia kwoty
# 2613	przez wartość
# 2621	towarów określoną
# 2631	kwoty prowizji
# 2646	podatników dokonujących
# 2651	sprzedaży będącej
# 26617	będącej przedmiotem
# 2679	przedmiotem umowy
# 26814	wartość sprzedanych
# 26912	sprzedanych towarów
# 2701	towarów będącej
# 2713	podatnicy będący
# 2722	będący zakładami
# 2735	zakładami pracy
# 27420	pracy chronionej
# 2753	chronionej w
# 2761099	przepisów o
# 27782	o zatrudnieniu
# 27879	zatrudnieniu i
# 27923	i rehabilitacji
# 28070	rehabilitacji zawodowej
# 281100	osób niepełnosprawnych
# 2821	niepełnosprawnych mogą
# 2832	mogą wybrać
# 2841	wybrać zwolnienie
# 28590	zwolnienie od
# 286198	bez względu
# 2871350	względu na
# 28815	na wartość
# 2896	warunkiem złożenia
# 29076	złożenia przez
# 291109	przez podatnika
# 2921	podatnika pisemnego
# 2931	oświadczenia we
# 29465	we właściwym
# 29515	właściwym urzędzie
# 2961	podatnik rozpoczynający
# 2971	rozpoczynający wykonywanie
# 29878	wykonywanie czynności
# 29932	czynności określonych
# 30098	ciągu roku
# 301104	roku podatkowego
# 3022	podatkowego może
# 3034	może wybrać
# 3042	jeżeli przewidywana
# 3054	przewidywana przez
# 306154	określona w
# 3074	w złożonym
# 30829	nie przekroczy
# 30913	w proporcji
# 31013	proporcji do
# 311150	do okresu
# 3121	prowadzonej sprzedaży
# 3132	kwoty wymienionej
# 314414	wymienionej w
# 3151	podatnik składa
# 31611	składa oświadczenie
# 3178	oświadczenie w
# 3183	dniem dokonania
# 3193	dokonania pierwszej
# 3203	pierwszej sprzedaży
# 3211	towarów określona
# 3226	określona zgodnie
# 3232	zostanie przekroczona
# 3244	przekroczona w
# 3252	moc od
# 32614	od momentu
# 3271	momentu przekroczenia
# 3283	opodatkowaniu podlega
# 3291	nadwyżka sprzedaży
# 3305	ponad wartość
# 3311	wartość określoną
# 3329	określoną zgodnie
# 3333	a obowiązek
# 33425	zdanie trzecie
# 3354	trzecie stosuje
# 3366	jeżeli podatnicy
# 3372	podatnicy określeni
# 33814	określeni w
# 3398	związki z
# 3401	tak układają
# 3413	układają swoje
# 3421	uzyskują wartość
# 3431	towarów znacznie
# 3441	znacznie niższą
# 34515	niższą niż
# 3461	uzyskaliby w
# 3471	gdyby związek
# 3485	związek ten
# 349117	ten nie
# 350859	w wyniku
# 3518	wyniku tych
# 3522	tych związków
# 3531	związków nastąpiło
# 3541	nastąpiło zmniejszenie
# 3551	zmniejszenie wpływów
# 3561	podatku traci
# 35757	początku roku
# 3581	ulega corocznie
# 3592	corocznie podwyższeniu
# 36010	podwyższeniu w
# 36171	w stopniu
# 36211	odpowiadającym wskaźnikowi
# 3636	wskaźnikowi cen
# 3644	cen konsumpcyjnych
# 3654	konsumpcyjnych towarów
# 36669	usług w
# 3671215	w okresie
# 36817	okresie pierwszych
# 3697	pierwszych trzech
# 37010	trzech kwartałów
# 371123	roku poprzedzającego
# 372106	poprzedzającego rok
# 37326	rok kalendarzowy
# 3749	kalendarzowy w
# 3751203	w stosunku
# 3761124	stosunku do
# 377204	tego samego
# 3784	samego okresu
# 3798	okresu roku
# 3802	podatników określonych
# 3813809	określonych w
# 3828	do importu
# 38330	wyroby z
# 38414	metali szlachetnych
# 3851	szlachetnych lub
# 386419	lub z
# 387201	z udziałem
# 3882	wyrobów wymienionych
# 389364	w załączniku
# 390278	załączniku nr
# 39157	świadczących usługi
# 3922	usługi prawnicze
# 3932	prawnicze oraz
# 39413	oraz usługi
# 395122	usługi w
# 396264	minister finansów
# 397160	i pkt
# 3982	uwzględnieniem klasyfikacji
# 3993	klasyfikacji wydanych
# 40043	o statystyce
# 40165	finansów w
# 4021564	w porozumieniu
# 4031606	porozumieniu z
# 40477	z prezesem
# 40518	prezesem głównego
# 406135	urzędu statystycznego
# 4071	statystycznego ustala
# 4082	ustala do
# 40923	listopada roku
# 4107	uwzględnieniem zasady
# 4113	zasady określonej
# 412577	określonej w
# 41313	tę kwotę
# 4143	kwotę do
# 41535	do pełnych
# 416340	w zdaniu
# 41760	zdaniu drugim
# 41819	drugim po
# 419540	po wyrazie
# 420236	się wyraz
# 42118	podstawą opodatkowania
# 42279	opodatkowania w
# 4239	w imporcie
# 4248	imporcie towarów
# 4257	towarów jest
# 42650	jest wartość
# 42712	celna powiększona
# 42838	powiększona o
# 42920	o należne
# 4306	należne cło
# 4318	cło i
# 43211	i podatek
# 4337	przedmiotem importu
# 4342	importu są
# 43522	są towary
# 4364	towary opodatkowane
# 4377	opodatkowane podatkiem
# 43816	wartość celną
# 4391	celną powiększoną
# 44021	powiększoną o
# 4411	importowy zwiększa
# 44225	zwiększa się
# 44329	również o
# 444673	się wyrazem
# 44511	obniżenie kwoty
# 44631	kwoty podatku
# 447476	następuje w
# 44820	w rozliczeniu
# 44910	rozliczeniu za
# 45014	którym podatnik
# 4514	rachunek uproszczony
# 4522	uproszczony w
# 45376	przypadku określonym
# 45410	lub dokument
# 4554	dokument odprawy
# 456420	albo w
# 4571	kropkę skreśla
# 45888	się i
# 4591227	miesięcy od
# 46086	od końca
# 4613	podatnik otrzymał
# 4622	otrzymał fakturę
# 46333	przypadku nabycia
# 46416	procentowy udział
# 4651	udział wartości
# 4666	wartości sprzedaży
# 4676	towarów opodatkowanych
# 46814	w wartości
# 4691	sprzedaży ogółem
# 4701	ogółem oblicza
# 471113	oblicza się
# 4721470	się na
# 4731	podstawie sprzedaży
# 4748	sprzedaży z
# 47512	z ostatnich
# 4762	ostatnich sześciu
# 4774	podatnicy dokonujący
# 4785	okresie krótszym
# 47974	krótszym niż
# 48019	niż sześć
# 48123	sześć miesięcy
# 4821	miesięcy obliczają
# 4832	udział zgodnie
# 484266	przy czym
# 4853	czym po
# 4861539	po upływie
# 48721	od rozpoczęcia
# 48855	rozpoczęcia działalności
# 4891	działalności wyliczają
# 4901	wyliczają ten
# 4914	i dokonują
# 4921	dokonują korekty
# 4933	korekty podatku
# 49418	gdy kwota
# 4952	kwota zwrotu
# 4964	podatku dla
# 4978	dla podatnika
# 4982	dokonującego sprzedaży
# 4991	opodatkowanych stawkami

# %%
# Sort the word pairs according to that measure in the descending order and determine top 10 entries.
list_PMI = []
for i in bills_bigrams_with_PMI:
    list_PMI.append([i,bills_bigrams_with_PMI[i][3],bills_bigrams_with_PMI[i][2]])
list_PMI.sort(key=lambda a: -a[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d49865e5e0aa> in <module>
#       1 # Sort the word pairs according to that measure in the descending order and determine top 10 entries.
#       2 list_PMI = []
# ----> 3 for i in bills_bigrams_with_PMI:
#       4     list_PMI.append([i,bills_bigrams_with_PMI[i][3],bills_bigrams_with_PMI[i][2]])
#       5 list_PMI.sort(key=lambda a: -a[1])
#
# NameError: name 'bills_bigrams_with_PMI' is not defined

# %%
list_PMI[0:10]

# %%
filtered_PMI = [ t for t in list_PMI if t[2] > 4]

# %%
filtered_PMI[0:10]

# %%
from math import log
import numpy as np

# Data

all_occurences = 0
for i in bills_bigrams:
    all_occurences += bills_bigrams[i]

bills_bigrams_with_LLR = {}

def H(args,N):
    s = 0
    for a in args:
        a /= N
        one = 1 if a == 0 else 0
        s += a * log(a + one)
    return s

def LLR_bigram(t1,t2,N):
    t1,t2 = i
    N = all_occurences
    
    k11 = (bills_bigrams[(t1,t2)])
    k12 = (bills_single_grams[t2] - k11)
    k21 = (bills_single_grams[t1] - k11)
    k22 = (all_occurences - k11 - k12 - k21)
    
    return 2 * N * (H([k11,k12,k21,k22],N) - H([k11+k12,k21+k22],N) - H([k11+k21,k12+k22],N))
    
N = all_occurences
for i in bills_bigrams:
    t1,t2 = i    
#     k11 = (bills_bigrams[(t1,t2)])
#     k12 = (bills_single_grams[t2] - k11)
#     k21 = (bills_single_grams[t1] - k11)
#     k22 = (all_occurences - k11 - k12 - k21)
    
#     LLR = 2 * N * (H([k11,k12,k21,k22],N) - H([k11+k12,k21+k22],N) - H([k11+k21,k12+k22],N))
    
    LLR = LLR_bigram(t1,t2,N)

    bills_bigrams_with_LLR[(t1,t2)] = LLR

# %%
list_LLR = []
for i in bills_bigrams_with_LLR:
    list_LLR.append([i,bills_bigrams_with_LLR[i]])
list_LLR.sort(key=lambda a: -a[1])
list_LLR[0:10]

# %%
import regex as re
to_remove = []

def fremove_token(t):
    tmp = re.search(r"\p{L}+",t)
    if tmp is None or len(tmp.group(0)) != len(t):
        return True
    return False
    
for i in bills_trigrams:
    t1,t2,t3 = i
    if fremove_token(t1) or fremove_token(t2) or fremove_token(t3):
        to_remove += [(t1,t2,t3)]

len(to_remove)

# %%
len(bills_trigrams)

# %%
for i in to_remove:
    bills_trigrams.pop(i)
len(bills_trigrams)

# %%
bills_trigrams_with_PMI = {}

for i in bills_trigrams:
    t1, t2, t3 = i
    f1, f2, f3, f123 = bills_single_grams[t1], bills_single_grams[t2],bills_single_grams[t3] , bills_trigrams[(t1,t2,t3)]
    bills_trigrams_with_PMI[(t1,t2,t3)] = (f1,f2,f3,f123,log(f123/(f1*f2*f3)))

# %%
list_trigrams_PMI = []
for i in bills_trigrams_with_PMI:
    list_trigrams_PMI.append([i,bills_trigrams_with_PMI[i][3],bills_trigrams_with_PMI[i][4]]) # tokens, together,
    
list_trigrams_PMI = [ t for t in list_trigrams_PMI if t[1] > 4]
list_trigrams_PMI.sort(key=lambda a: -a[2])
list_trigrams_PMI[0:10]

# %%
from math import log
import numpy as np

# Data

all_occurences_trigram = 0
for i in bills_trigrams:
    all_occurences_trigram += bills_trigrams[i]


bills_trigrams_with_LLR = {}


N = all_occurences_trigram

for i in bills_trigrams:
    # we treat t1t2 and t3 as singlegram
    t1,t2,t3  = i
    
    k11 = (bills_trigrams[(t1,t2,t3)])
    k12 = (bills_single_grams[t3] - k11)
    k21 = (bills_bigrams[(t1,t2)] - k11)
    k22 = (all_occurences_trigram - k11 - k12 - k21)
    
    LLR = 2 * N * (H([k11,k12,k21,k22],N) - H([k11+k12,k21+k22],N) - H([k11+k21,k12+k22],N))

    bills_trigrams_with_LLR[(t1,t2,t3)] = LLR

# %%
list_trigrams_LLR = []
for i in bills_trigrams_with_LLR:
    list_trigrams_LLR.append([i,bills_trigrams_with_LLR[i]])
list_trigrams_LLR.sort(key=lambda a: -a[1])
list_trigrams_LLR[0:10]

# %%
# Create a table comparing the methods (separate table for bigrams and trigrams).

# %% [markdown]
# # Answer the following questions:
#     Why do we have to filter the bigrams, rather than the token sequence?
#
#     Which measure (PMI, PMI with filtering, LLR) works better for the bigrams and which for the trigrams?
#         For bigrams LLR worked best - because sequence found have more occurences than almost minimal.
#         Both PMI and PMI wth filtering  found unique sequences which separatly does not appear
#
#         There is similar situation regarding trigrams. But PMI found uniquely connected sequences like 'piłce', 'nożnej', 'uefa'
#     What types of expressions are discovered by the methods.
#         As said before
#             PMI - unique sequences that only appear together
#             LLR - most common sequences thaet appear togather
#     Can you devise a different type of filtering that would yield better results?
#         1) Maybe merging two of these methods.
#             Taking ranks of each sequence in each method then makinmg average or weighted average to balance the finale result.
#         2) Taking PMI result but make the filter more restrictive, i mean more occurences in text.
